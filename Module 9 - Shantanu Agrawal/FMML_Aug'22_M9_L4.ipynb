# %% [markdown]
# # Foundation of Modern Machine Learning
# ## Module 9: Neural Networks
# ### Lab 4: Visulaizing MLP and Backpropagation
# #### Module Coordinator: Shantanu Agrawal

# %% [markdown]
# In this session, we would try to visualize the architecture of a self-designed model using the **Tensorflow Playground** GUI. And how the model coefficents changes with the increase of epochs in the tarining of the model.
#
# #### NOTE: Try to look for every parameter or options given in the page and tune the values of those variables to observe the change.

# %% [markdown]
# ## We use [Tensorflow Playground](https://playground.tensorflow.org) which provides an easy way to play around with neural network architectures.
#
#
# ## Try performing the following experiments and report your results. Are there any observations you can make?

# %% [markdown]
# ![Screenshot 2022-09-06 175017.png](data:image/png;base64,...)

# %% [markdown]
# # Introducing a hidden layer
#
#
# 1.   Pick any non-linearly separable dataset.
# 2.   Set number of hidden layers to 0 and train.
# 3.   Add a hidden layer and train.

# %% [markdown]
# # Appreciating non-linear activations
#
#
# 1.   Set activation function to linear.
# 2.   Set activation function as sigmoid. Do you observe any differences?
# 3.   Try other activation functions such as ReLU etc.

# %% [markdown]
# # Regularisation
#
# 1. Try training with and without regularisation.
# 2. Also try L1, L2 regularisation
# 3. Experiment with regularisation rates.

# %% [markdown]
# # Other experiments
#
# 1. Try changing to regression/classification task and observing the results.
# 2. Try changing number of neurons in hidden layer.

# %% [markdown]
# # Tasks
#
# Post at least 3 sets of pictures of the front page of the website, and also describe (in text) the changes you have tried and how it have impacted the result, it can be a good or bad impact :')<br>
# *Bonus*: Describe how the change have resulted in your mentioned manner?
